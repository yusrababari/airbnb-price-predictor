# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Machine Learning models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# Model evaluation & validation
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Libraries successfully imported!")
# Out:
# Libraries successfully imported!

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('listings.csv')

# Shuffle and split 80/20 (80% for training the model and 20% for testing)
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
split = int(0.8 * len(df))

train = df.iloc[:split].reset_index(drop=True)
test = df.iloc[split:].reset_index(drop=True)

print(f"Loaded train shape: {train.shape}")
print(f"Loaded test shape: {test.shape}")
# Out:
# Loaded train shape: (77496, 18)
# Loaded test shape: (19375, 18)

# %%
df.head(3)
df.tail(3)
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 96871 entries, 0 to 96870
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              96871 non-null  int64
#  1   name                            96871 non-null  str
#  2   host_id                         96871 non-null  int64
#  3   host_name                       96828 non-null  str
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   96871 non-null  str
#  6   latitude                        96871 non-null  float64
#  7   longitude                       96871 non-null  float64
#  8   room_type                       96871 non-null  str
#  9   price                           61963 non-null  float64
#  10  minimum_nights                  96871 non-null  int64
#  11  number_of_reviews               96871 non-null  int64
# ...

# %% [markdown]
# #List every column and decide which ones are relevant to price
#
#  neighbourhood_group
#  neighbourhood
#    latitude
#      longitude
#     room_type
#     price
#   minimum_nights
#    number_of_reviews
#    last_review
#   reviews_per_month
#    calculated_host_listings_count
#    availability_365
#    number_of_reviews_ltm

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                            43
# neighbourhood_group               96871
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             34908
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       24122
# reviews_per_month                 24122
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           96871
# dtype: int64
