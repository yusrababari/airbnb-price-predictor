# %%
#Drop the license column as it is empty
# tutorial:https://www.w3schools.com/python/pandas/pandas_cleaning_wrong_format.asp
import pandas as pd

df = pd.read_csv('listings.csv')
new_df = df.dropna(license)
print(new_df.to_string())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2
#       3 import pandas as pd
#       4
#       5 df = pd.read_csv('listings.csv')
# ----> 6 new_df = df.dropna(license)
#       7 print(new_df.to_string())
#       8
#
# TypeError: DataFrame.dropna() takes 1 positional argument but 2 were given
